# %% [markdown]
# # 1. Label Flipping method :

# %% [markdown]
# ## 1.1 Scenario I :
# Single Client targeted ( client number 1) + verified clients number 0, 1, 2

# %% [markdown]
# ### 1.1.1 10 clients:

# %% [markdown]
# #### 1.1.1.1 10 clients + Fedopt

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "label_flip",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="label-flip-scenario1-fedopt-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: label-flip-scenario1-fedopt-10clients-e-2025-11-15-21-51-26-025

# %% [markdown]
# #### 1.1.1.2 10 clients + FedAVG

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "label_flip",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="label-flip-scenario1-fedavg-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: label-flip-scenario1-fedavg-10clients-e-2025-11-15-23-18-38-466

# %% [markdown]
# ### 1.1.2 20 clients:

# %% [markdown]
# #### 1.1.2.1 20 clients + Fedopt

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 20,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 18,
    "local_epochs": 3,
    "batch_size": 64, # from cifar10 64 
    "client_lr": 0.0025, 
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.25,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "label_flip",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="label-flip-scenario1-fedopt-20clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: label-flip-scenario1-fedopt-20clients-e-2025-11-17-08-01-46-649

# %% [markdown]
# #### 1.1.2.1 20 clients + FedAVG

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 20,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 18,
    "local_epochs": 3,
    "batch_size": 64, 
    "client_lr": 0.0025, 
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.25,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "label_flip",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="label-flip-scenario1-fedavg-20clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: label-flip-scenario1-fedavg-20clients-e-2025-11-17-14-28-29-202

# %% [markdown]
# ## 1.2 Scenario II :
# Subset of  clients targeted:
# - in the case of 20 clients ( two clients targeted ( 0, 1) + two verified ( 1, 2))
# - in the case of 50 clients (four clients targeted (0, 1, 2, 3) + four verified (2, 3, 4, 5))

# %% [markdown]
# ### 1.2.1 10 clients

# %% [markdown]
# #### 1.2.1.1 Fedopt

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "label_flip",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "0 1",
    "verified_clients": "1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g5.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="label-flip-sc2-fedopt-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: label-flip-sc2-fedopt-10clients-eurosat-2025-11-18-19-31-55-750

# %% [markdown]
# #### 1.2.1.2 Fedavg

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "label_flip",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "0 1",
    "verified_clients": "1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir2.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g6.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="label-flip-sc2-fedavg-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: label-flip-sc2-fedavg-10clients-eurosat-2025-11-18-22-21-22-448

# %% [markdown]
# # 2. Backdoor Trigger

# %% [markdown]
# ## 2.1 Scenario 1 :

# %% [markdown]
# ### 2.1.1 10 clients

# %% [markdown]
# #### 2.1.1.1 Fedopt

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "backdoor",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="backdoor-scenario1-fedopt-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: backdoor-scenario1-fedopt-10clients-eur-2025-11-16-10-18-10-856

# %% [markdown]
# #### 2.1.1.2 FedAvg

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "backdoor",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="backdoor-scenario1-fedavg-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: backdoor-scenario1-fedavg-10clients-eur-2025-11-16-13-41-28-312

# %% [markdown]
# ### 2.1.2 20 clients

# %% [markdown]
# #### 2.1.2.1 Fedopt

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 20,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 18,
    "local_epochs": 3,
    "batch_size": 64, 
    "client_lr": 0.0025, 
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.25,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "backdoor",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir2.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="backdoor-scenario1-fedopt-20clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: backdoor-scenario1-fedopt-20clients-eur-2025-11-17-14-52-10-743

# %% [markdown]
# #### 2.1.2.2 Fedavg:

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 20,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 18,
    "local_epochs": 3,
    "batch_size": 64, 
    "client_lr": 0.0025, 
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.25,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "backdoor",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir2.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="backdoor-scenario1-fedavg-20clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: backdoor-scenario1-fedavg-20clients-eur-2025-11-17-22-02-23-832

# %% [markdown]
# ## 2.2 Scenario 2:

# %% [markdown]
# ### 2.2.1 10 clients:

# %% [markdown]
# #### 2.2.1.1 Fedopt:

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "backdoor",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "0 1",
    "verified_clients": "1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g6.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="backdoor-sc2-fedopt-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: backdoor-sc2-fedopt-10clients-eurosat-2025-11-18-23-34-00-838

# %% [markdown]
# #### 2.2.1.2 Fedavg

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "backdoor",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "0 1",
    "verified_clients": "1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir2.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g6.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="backdoor-sc2-fedavg-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: backdoor-sc2-fedavg-10clients-eurosat-2025-11-19-00-58-00-798

# %% [markdown]
# ### 2.2.2 20 clients:

# %% [markdown]
# # 3. Fingerprinting

# %% [markdown]
# ## 3.1 Scenario 1

# %% [markdown]
# ### 3.1.1 10 clients

# %% [markdown]
# #### 3.1.1.1 Fedopt

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "fingerprint",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="fingerprint-scenario1-fedopt-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: fingerprint-scenario1-fedopt-10clients--2025-11-16-17-42-00-107

# %% [markdown]
# #### 3.1.1.2 FedAvg

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "fingerprint",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="fingerprint-scenario1-fedavg-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: fingerprint-scenario1-fedavg-10clients--2025-11-16-22-41-12-569

# %% [markdown]
# ### 3.1.2 20 clients

# %% [markdown]
# #### 3.1.2.1 Fedopt

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 20,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 18,
    "local_epochs": 3,
    "batch_size": 64, 
    "client_lr": 0.0025, 
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.25,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "fingerprint",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="fingerprint-scenario1-fedopt-20clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: fingerprint-scenario1-fedopt-20clients--2025-11-17-22-09-09-024

# %% [markdown]
# #### 3.1.2.2 Fedavg

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 20,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 18,
    "local_epochs": 3,
    "batch_size": 64, 
    "client_lr": 0.0025, 
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.25,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "fingerprint",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "1",
    "verified_clients": "0 1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g4dn.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="fingerprint-scenario1-fedavg-20clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: fingerprint-scenario1-fedavg-20clients--2025-11-18-09-45-16-244

# %% [markdown]
# ## 3.2 Scenario 2

# %% [markdown]
# ### 3.2.1 10 clients

# %% [markdown]
# #### 3.2.1.1 Fedopt

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedopt",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "fingerprint",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "0 1",
    "verified_clients": "1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g6.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="fingerprint-sc2-fedopt-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: fingerprint-sc2-fedopt-10clients-eurosa-2025-11-19-08-10-52-634

# %% [markdown]
# #### 3.2.1.2 Fedavg

# %%
from sagemaker.huggingface import HuggingFace

role = "arn:aws:iam::711387130895:role/service-role/SageMaker-ExecutionRole-20250525T120088"

# Define hyperparameters that match your argparse arguments
hyperparameters = {
    # --- Dataset and client setup ---
    "dataset_name": "eurosat",
    "num_clients": 10,
    "frac_clients": 1.0,
    "dirichlet_alpha": 0.5,
    "test_size": 0.2,
    "poison_size": 0.3,

    # --- Training parameters ---
    "rounds": 16,
    "local_epochs": 3,
    "batch_size": 32, # from cifar10 64 
    "client_lr": 0.002,
    "client_momentum": 0.9,
    "weight_decay": 1e-4,

    # --- Server optimisation ---
    "server_opt": "fedavg",
    "server_lr": 0.15,

    # --- Fingerprinting ---
    "enable_fingerprinting": "1",          # or False if disabled
    "fingerprint_method": "sparse",         # choices: ["sparse", "dense"]
    "fingerprint_sparsity": 0.01,
    "target_dot_strength": 1.0,

    # --- Detection / Defence params ---
    "honest_fraction": 0.1,
    "detection_margin": 1.5,
    "seed": 42,
    "history_window": 5,
    "method": "fingerprint",                 # choices: ["label_flip", "backdoor","fingerprint"]
    "label_flip_alpha": 1.0,
    "backdoor_target_label": 1,
    "backdoor_patch_size": 15,
    "backdoor_intensity": 1.0,
    "tau_backdoor_threshold_statistical": tau_stat,
    "tau_backdoor_threshold_emprical": tau_emp,


    # --- Client selection ---
    # Lists must be passed as space-separated strings for SageMaker
    "targeted_clients": "0 1",
    "verified_clients": "1 2",
}


huggingface_estimator = HuggingFace(
    entry_point="main.py",   # script inside source_dir
    source_dir="s3://poison-detect-bucket/submission2/scripts/sourcedir2.tar.gz",  # zipped dir
    role=role,
    instance_type="ml.g6.12xlarge",  # use quota for faster training
    instance_count=1,
    transformers_version="4.36.0",
    pytorch_version="2.1.0",
    py_version="py310",
    base_job_name="fingerprint-sc2-fedavg-10clients-eurosat",
    hyperparameters=hyperparameters,  # pass args here
)

# Launch training
huggingface_estimator.fit(wait=False)
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: fingerprint-sc2-fedavg-10clients-eurosa-2025-11-19-08-11-47-343

# %% [markdown]
# ### 3.2.2 20 clients
